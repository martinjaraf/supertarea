# %% [markdown]
# # Tarea Grande 1
#
# ##### Nombres: Martín Jara, Joaquín Fuentealba
#
# ## Importación de librerías
#
# En la siguiente celda, se importarán las librerías que serán utilizadas para esta parte de la tarea. Si deseas utilizar una librería adicional y que no sea *built-in*, repórtala en el ```README.md``` de tu repositorio. Solo así podremos saber que necesitamos instalar algo más para ejecutar tu tarea y evaluarla.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %% [markdown]
# ## Cargar datos

# %%
#averiguar como llegar al csv anime_clean 
#en carpeta dataset desde carpeta parte_1
data_animes = path= "./../dataset/"
data_animes = pd.read_csv (path + 'anime_clean.csv', sep = ',')

# %%
data_animes.head(10)
# Out:
#    MAL_ID                             Name  Score   Type  Episodes  Watching  \
# 0       1                     Cowboy Bebop   8.78     TV        26    105808
# 1       5  Cowboy Bebop: Tengoku no Tobira   8.39  Movie         1      4143
# 2       6                           Trigun   8.24     TV        26     29113
# 3       7               Witch Hunter Robin   7.27     TV        26      4300
# 4       8                   Bouken Ou Beet   6.98     TV        52       642
# 5      15                     Eyeshield 21   7.95     TV       145     13907
# 6      16             Hachimitsu to Clover   8.06     TV        24     11909
# 7      17       Hungry Heart: Wild Striker   7.59     TV        52       817
# 8      18           Initial D Fourth Stage   8.15     TV        24      6082
# 9      19                          Monster   8.76     TV        74     64648
#
#    Completed  Plan to Watch   Season     Year
# 0     718161         329800   Spring     1998
# ...

# %%
scores_animes = data_animes["Score"]

# %%
sns.histplot(scores_animes).set_title('Distribucion de puntajes animes')
# Out:
# Text(0.5, 1.0, 'Distribucion de puntajes animes')

# %%
sns.kdeplot(data=scores_animes, shade=True).set_title('Distribucion de densidad')
# Out:
# Text(0.5, 1.0, 'Distribucion de densidad')

# %%
movie = data_animes.groupby("Type").get_group('Movie')
scores_animes_movie = movie["Score"]
sns.histplot(scores_animes_movie).set_title('Distribucion de puntajes animes movie')
# Out:
# Text(0.5, 1.0, 'Distribucion de puntajes animes movie')

# %%
sns.kdeplot(data=scores_animes_movie, shade=True).set_title('Distribucion de densidad movie')
# Out:
# Text(0.5, 1.0, 'Distribucion de densidad movie')

# %%
tv = data_animes.groupby("Type").get_group('TV')
scores_animes_tv = tv["Score"]
sns.histplot(scores_animes_tv).set_title('Distribucion de puntajes animes TV')
# Out:
# Text(0.5, 1.0, 'Distribucion de puntajes animes TV')

# %%
sns.kdeplot(data=scores_animes_tv, shade=True).set_title('Distribucion de densidad TV')
# Out:
# Text(0.5, 1.0, 'Distribucion de densidad TV')

# %%
ona = data_animes.groupby("Type").get_group('ONA')
scores_animes_ona = ona["Score"]
sns.histplot(scores_animes_ona).set_title('Distribucion de puntajes animes ONA')
# Out:
# Text(0.5, 1.0, 'Distribucion de puntajes animes ONA')

# %%
sns.kdeplot(data=scores_animes_ona, shade=True).set_title('Distribucion de densidad ONA')
# Out:
# Text(0.5, 1.0, 'Distribucion de densidad ONA')

# %%
music = data_animes.groupby("Type").get_group('Music')
scores_animes_music = music["Score"]
sns.histplot(scores_animes_music).set_title('Distribucion de puntajes animes music')
# Out:
# Text(0.5, 1.0, 'Distribucion de puntajes animes music')

# %%
sns.kdeplot(data=scores_animes_music, shade=True).set_title('Distribucion de densidad music')
# Out:
# Text(0.5, 1.0, 'Distribucion de densidad music')

# %%
ova = data_animes.groupby("Type").get_group('OVA')
scores_animes_ova = ova["Score"]
sns.histplot(scores_animes_ova).set_title('Distribucion de puntajes animes OVA')
# Out:
# Text(0.5, 1.0, 'Distribucion de puntajes animes OVA')

# %%
sns.kdeplot(data=scores_animes_ova, shade=True).set_title('Distribucion de densidad OVA')
# Out:
# Text(0.5, 1.0, 'Distribucion de densidad OVA')

# %%
special = data_animes.groupby("Type").get_group('Special')
scores_animes_special = special["Score"]
sns.histplot(scores_animes_special).set_title('Distribucion de puntajes animes special')
# Out:
# Text(0.5, 1.0, 'Distribucion de puntajes animes special')

# %%
sns.kdeplot(data=scores_animes_special, shade=True).set_title('Distribucion de densidad special')
# Out:
# Text(0.5, 1.0, 'Distribucion de densidad special')

# %%
sns.kdeplot(data=scores_animes_movie, shade=True)
sns.kdeplot(data=scores_animes_tv, shade=True)
sns.kdeplot(data=scores_animes_ona, shade=True)
sns.kdeplot(data=scores_animes_music, shade=True)
sns.kdeplot(data=scores_animes_ova, shade=True)
sns.kdeplot(data=scores_animes_special, shade=True).set_title('Distribucion de densidad para grupos segun tipo')
# Out:
# Text(0.5, 1.0, 'Distribucion de densidad para grupos segun tipo')

# %%
sns.histplot(scores_animes_movie, color='red')

sns.histplot(scores_animes_tv, color='green')

sns.histplot(scores_animes_ona, color='yellow')

sns.histplot(scores_animes_music, color='grey')

sns.histplot(scores_animes_ova, color='purple')

sns.histplot(scores_animes_special, color='blue').set_title('Distribucion de puntajes animes segun su tipo')
# Out:
# Text(0.5, 1.0, 'Distribucion de puntajes animes segun su tipo')
